# %% [markdown]
# # Task 05

# %% [markdown]
# # Import Labraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Dataset

# %%
df=pd.read_csv("C:\\Users\\absub\\Downloads\\BigML_Dataset_5fde1fade84f94757d00135a.csv")
df
# Out:
#                State Atmospheric Condition  Crash Date  Fatalities in crash  \
# 0             Alaska                 Clear  2011-01-05                    1
# 1             Alaska                 Clear  2011-01-05                    1
# 2            Arizona                 Clear  2011-01-01                    1
# 3            Arizona                 Clear  2011-01-01                    1
# 4            Arizona                 Clear  2011-01-01                    1
# ...              ...                   ...         ...                  ...
# 4994      New Jersey                 Clear  2011-01-31                    1
# 4995        New York                  Snow  2011-01-21                    1
# 4996  North Carolina                 Clear  2011-01-16                    1
# 4997    North Dakota                 Clear  2011-08-27                    1
# 4998            Ohio                  Rain  2011-03-05                    1
#
# ...

# %%
#Looking first five information from dataset
df.head()
# Out:
#      State Atmospheric Condition  Crash Date  Fatalities in crash  \
# 0   Alaska                 Clear  2011-01-05                    1
# 1   Alaska                 Clear  2011-01-05                    1
# 2  Arizona                 Clear  2011-01-01                    1
# 3  Arizona                 Clear  2011-01-01                    1
# 4  Arizona                 Clear  2011-01-01                    1
#
#                                Roadway   Age  Alcohol Results  \
# 0  Rural-Principal Arterial-Interstate  27.0              0.0
# 1  Rural-Principal Arterial-Interstate  60.0              0.0
# 2       Urban-Other Principal Arterial  24.0              NaN
# 3       Urban-Other Principal Arterial  27.0              0.0
# 4       Urban-Other Principal Arterial  82.0              0.0
#
#                                  Person Type Drug Involvement     Race  \
# 0     Driver of a Motor Vehicle In-Transport              Yes      NaN
# ...

# %%
#Looking last five information from dataset
df.tail()
# Out:
#                State Atmospheric Condition  Crash Date  Fatalities in crash  \
# 4994      New Jersey                 Clear  2011-01-31                    1
# 4995        New York                  Snow  2011-01-21                    1
# 4996  North Carolina                 Clear  2011-01-16                    1
# 4997    North Dakota                 Clear  2011-08-27                    1
# 4998            Ohio                  Rain  2011-03-05                    1
#
#                              Roadway   Age  Alcohol Results  \
# 4994            Urban-Minor Arterial  44.0              NaN
# 4995            Urban-Minor Arterial  30.0              NaN
# 4996  Urban-Other Principal Arterial  81.0              NaN
# 4997  Urban-Other Principal Arterial  50.0             0.13
# 4998           Rural-Minor Collector  24.0             0.26
#
#                                  Person Type Drug Involvement   Race  Gender  \
# ...

# %%
#Detaills about columns
df.columns
# Out:
# Index(['State', 'Atmospheric Condition', 'Crash Date', 'Fatalities in crash',
#        'Roadway', 'Age', 'Alcohol Results', 'Person Type', 'Drug Involvement',
#        'Race', 'Gender', 'Injury Severity', 'Crash Date.year',
#        'Crash Date.month', 'Crash Date.day-of-month',
#        'Crash Date.day-of-week'],
#       dtype='object')

# %%
df.dtypes.value_counts()
# Out:
# object     9
# int64      5
# float64    2
# dtype: int64

# %%
#looking shape of dataset
df.shape
# Out:
# (4999, 16)

# %%
#Getting statistical information about dataset
df.describe()
# Out:
#        Fatalities in crash          Age  Alcohol Results  Crash Date.year  \
# count          4999.000000  4929.000000      2293.000000           4999.0
# mean              1.138628    38.608237         0.058696           2011.0
# std               0.425039    20.305162         0.095707              0.0
# min               1.000000     0.000000         0.000000           2011.0
# 25%               1.000000    22.000000         0.000000           2011.0
# 50%               1.000000    36.000000         0.000000           2011.0
# 75%               1.000000    53.000000         0.120000           2011.0
# max               5.000000    98.000000         0.650000           2011.0
#
#        Crash Date.month  Crash Date.day-of-month  Crash Date.day-of-week
# count       4999.000000              4999.000000             4999.000000
# mean           2.508702                13.647930                4.245849
# std            2.201048                 8.802106                2.011116
# ...

# %%
df['Atmospheric Condition'].value_counts()
# Out:
# Clear                                     3220
# Cloudy                                     845
# Snow                                       379
# Rain                                       309
# Sleet, Hail (Freezing Rain or Drizzle)      96
# Fog, Smog, Smoke                            65
# Blowing Snow                                50
# Severe Crosswinds                           12
# Not Reported                                11
# Unknown                                      6
# Other                                        5
# Blowing Sand, Soil, Dirt                     1
# Name: Atmospheric Condition, dtype: int64

# %%
df['State'].value_counts()
# Out:
# Wyoming                 129
# Arizona                 123
# Colorado                121
# Idaho                   115
# Minnesota               115
# New Mexico              113
# Texas                   110
# Washington              110
# Arkansas                110
# Alabama                 110
# Kentucky                108
# Utah                    108
# Oregon                  108
# Delaware                106
# Kansas                  106
# South Carolina          105
# Hawaii                  103
# California              102
# Illinois                102
# New Hampshire           102
# Florida                 102
# Michigan                102
# South Dakota            102
# Montana                 101
# Alaska                  100
# West Virginia            99
# Maryland                 99
# Wisconsin                98
# Ohio                     98
# Tennessee                97
# North Carolina           96
# Connecticut              96
# Indiana                  96
# ...

# %%
fig,ax=plt.subplots(figsize=(10,5))
df['State'].value_counts()[:10].plot(kind='bar')
ax.set(title='Top 10 states by Number of Accidents',xlabel='States',ylabel='Accidents count')
plt.show()

# %%
df['Roadway'].value_counts()
# Out:
# Rural-Principal Arterial-Other                            823
# Urban-Other Principal Arterial                            596
# Rural-Major Collector                                     544
# Rural-Minor Arterial                                      461
# Rural-Principal Arterial-Interstate                       451
# Rural-Local Road or Street                                446
# Urban-Minor Arterial                                      415
# Urban-Principal Arterial-Interstate                       373
# Urban-Local Road or Street                                361
# Urban-Collector                                           192
# Urban-Principal Arterial-Other Freeways or Expressways    176
# Rural-Minor Collector                                     130
# Rural-Unknown Rural                                        26
# Urban-Unknown Urban                                         2
# Unknown                                                     2
# ...

# %%
fig,ax=plt.subplots(figsize=(16,8))
df['Roadway'].value_counts().plot(kind='bar')
ax.set(title='Roadway by Number of Accidents',xlabel='Roadway',ylabel='Accidents count')
plt.show()

# %%
df['Atmospheric Condition'].value_counts()
# Out:
# Clear                                     3220
# Cloudy                                     845
# Snow                                       379
# Rain                                       309
# Sleet, Hail (Freezing Rain or Drizzle)      96
# Fog, Smog, Smoke                            65
# Blowing Snow                                50
# Severe Crosswinds                           12
# Not Reported                                11
# Unknown                                      6
# Other                                        5
# Blowing Sand, Soil, Dirt                     1
# Name: Atmospheric Condition, dtype: int64

# %%
fig,ax=plt.subplots(figsize=(16,8))
df['Atmospheric Condition'].value_counts().plot(kind='bar')
ax.set(title='Atmospheric Condition by Number of Accidents',xlabel='Atmospheric Condition',ylabel='Accidents count')
plt.show()

# %%
plt.figure(figsize=(15,9))
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\absub\AppData\Local\Temp\ipykernel_10044\391768007.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# # Thank You
